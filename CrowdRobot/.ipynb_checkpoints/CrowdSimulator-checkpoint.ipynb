# %%
import numpy as np
import svg
import time
import env
from PedestrianClass import Pedestrian
from euclid import Circle, Point2, Vector2, LineSegment2
from IPython.display import clear_output, display, HTML
import matplotlib.pyplot as plt

import math

from env import num_pedestrains
from env import num_pedestrains
from env import radius_hh


crowd = []
xsize = 8
ysize = 8
amp = 80
offset = 30
ped_ra = 13
ped_buffersize = 2
ped_spdlimit = 4
ped_outcount = 0
ped_outflow = []
walls = [(Point2(0,0), Point2(xsize, 0)), 
         (Point2(0,0), Point2(0, ysize)), 
         (Point2(xsize/2, ysize/2), Point2(xsize, ysize/2)), 
         (Point2(xsize/2, ysize/2), Point2(xsize/2, ysize))
        ]

pos_rx = 1.5
pos_ry = 3

num_flowA = 180
num_flowB = 120

flowA_init_wide = 3.6
flowA_x_start = 0
flowA_y_start = 4

flowB_init_wide = 3.6
flowB_x_start = 0
flowB_y_start = 0

init_space_ped = 0.4

ped_accel_rate_limit = 1000

def init_flowAB():
    #init the position of flowA
    init_flowA_pos_list = []
    flowA_x_index = 0
    num_ped_each_row = int(math.floor(flowA_init_wide/init_space_ped))
    for flowA_index in range(num_flowA):
        flowA_y_index = 1 + flowA_index % num_ped_each_row
        if flowA_index % num_ped_each_row ==0:
            flowA_x_index += 1

        init_pos_x = flowA_x_start-init_space_ped*flowA_x_index 
        init_pos_y = flowA_y_start+init_space_ped*flowA_y_index
        init_flowA_pos_list.append(np.array( [init_pos_x, init_pos_y] ) )
        ped = Pedestrian(np.array([init_pos_x]), np.array([init_pos_y]), np.array([2.0]), np.array([0]), c='red')
        crowd.append(ped)

    #init the position of flowB    
    init_flowB_pos_list = []
    flowB_y_index = 0
    num_ped_each_row = int(math.floor(flowB_init_wide/init_space_ped))
    for flowB_index in range(num_flowB):
        flowB_x_index = 1 + flowB_index % num_ped_each_row
        if flowB_index % num_ped_each_row ==0:
            flowB_y_index += 1

        init_pos_x = flowB_x_start+init_space_ped*flowB_x_index
        init_pos_y = flowB_y_start-init_space_ped*flowB_y_index    
        init_flowB_pos_list.append(np.array( [init_pos_x, init_pos_y] ))    
        ped = Pedestrian(np.array([init_pos_x]), np.array([init_pos_y]), np.array([0]), np.array([2.0]), c='blue')
        crowd.append(ped)    


def build_scene():
    scene = svg.Scene((xsize*amp + 2*offset, ysize*amp + 2*offset + 40))
    # draw walls
    for wall in walls:
        p1 = wall[0] * amp + Point2(offset, offset)
        p2 = wall[1] * amp + Point2(offset, offset)
        scene.add(svg.Line(p1, p2))
    scene.add(svg.Rectangle(Point2(offset, offset), Point2(xsize*amp, ysize*amp)))
    return scene
    
def add_ped(num1, num2):
    for i in range(num1): #flowB
        rand = np.random.random([3])
        posX = rand[0] * 3 +0.5
        posY = -rand[1] * ped_buffersize - 3
        #VelX = rand[2]
        ped = Pedestrian(np.array([posX]), np.array([posY]), np.array([0]), np.array([2.0]), c='blue')
        crowd.append(ped)
        
    for i in range(num2): #flowA
        rand = np.random.random([3])
        posX = -rand[0] * ped_buffersize - 3
        posY = rand[1] * 3 + 4.5
        ped = Pedestrian(np.array([posX]), np.array([posY]), np.array([2.0]), np.array([0]), c='red')
        crowd.append(ped)
        
def move_crowd(robot_flag, time_step):
#     # check, remove and add
#     global ped_outcount, ped_outflow
#     to_remove = []
#     numblue = 0
#     numred = 0
#     for ped in crowd:
#         if ped.x > xsize:
#             to_remove.append(ped)
#             if ped.c == 'blue':
#                 numblue += 1
#             else:
#                 numred += 1
#     ped_outcount += numblue + numred
#     if step % 10 ==0:
#         ped_outflow.append(ped_outcount)
#         ped_outcount = 0

#     if to_remove is not None:
#         for ped in to_remove:
#             crowd.remove(ped)
#         add_ped(numblue, numred)
            
#     posX=[]
#     posY=[]
#     velX=[]
#     velY=[]
    
#     for ped in crowd:
#         posX.append(ped.x)
#         posY.append(ped.y)
#         # speed limit
#         spd = np.sqrt(ped.vx**2 + ped.vy**2)
#         if spd > ped_spdlimit:
#             ped.vx = (ped_spdlimit/spd)*ped.vx
#             ped.vy = (ped_spdlimit/spd)*ped.vy
#         velX.append(ped.vx)
#         velY.append(ped.vy)
#     pos_x = np.reshape(posX, [-1,1])
#     pos_y = np.reshape(posY, [-1,1])
#     vel_x = np.reshape(velX, [-1,1])
#     vel_y = np.reshape(velY, [-1,1])
    
    #print pos_x#, posY
        
        
    # check, remove and add
    global ped_outcount, ped_outflow
    #to_remove = []
    numblue = 0
    numred = 0
    for ped in crowd:
        if ped.x > xsize:
            #to_remove.append(ped)
            if ped.c == 'blue':
                numblue += 1
                rand = np.random.random([3])
                ped.x = np.array( [rand[0] * 3 +0.5] ) 
                ped.y = np.array( [-rand[1] * ped_buffersize - 3] ) 
                ped.vx = np.array( [0] )
                ped.vy = np.array([2.0])
            else:
                numred += 1
                rand = np.random.random([3])
                ped.x = np.array( [-rand[0] * ped_buffersize - 3] ) 
                ped.y = np.array( [rand[1] * 3 + 4.5] )  
                ped.vx = np.array([2.0])
                ped.vy = np.array([0])
                
                
    ped_outcount += numblue + numred
    if step % 10 ==0:
        ped_outflow.append(ped_outcount)
        ped_outcount = 0

#     if to_remove is not None:
#         for ped in to_remove:
#             crowd.remove(ped)
#         add_ped(numblue, numred)
            
    posX=[]
    posY=[]
    velX=[]
    velY=[]
    
    for ped in crowd:
        posX.append(ped.x)
        posY.append(ped.y)
        # speed limit
        spd = np.sqrt(ped.vx**2 + ped.vy**2)
        if spd > ped_spdlimit:
            ped.vx = (ped_spdlimit/spd)*ped.vx
            ped.vy = (ped_spdlimit/spd)*ped.vy
        velX.append(ped.vx)
        velY.append(ped.vy)
    pos_x = np.reshape(posX, [-1,1])
    pos_y = np.reshape(posY, [-1,1])
    vel_x = np.reshape(velX, [-1,1])
    vel_y = np.reshape(velY, [-1,1])    
    

    
    #f_hhi_matrix_x, f_hhi_matrix_y = env.human_human_force(pos_x, pos_y, time_step, vel_x, vel_y) 
    f_sd_x, f_sd_y, f_hhi_matrix_x, f_hhi_matrix_y = env.self_driven_force_and_human_human_force(pos_x, pos_y, time_step, vel_x, vel_y) 
    f_hhi_x = np.expand_dims( np.sum(f_hhi_matrix_x, axis=0), 1)
    f_hhi_y = np.expand_dims( np.sum(f_hhi_matrix_y, axis=0), 1)
    
    f_hwi_x, f_hwi_y = env.human_wall_force(pos_x, pos_y)
    #f_sd_x, f_sd_y = env.self_driven_force(pos_x, pos_y, vel_x, vel_y)
    if robot_flag:
        f_hri_x, f_hri_y = env.human_robot_force(pos_x, pos_y, pos_rx, pos_ry)
        f_comb_x = f_sd_x + f_hwi_x + f_hhi_x + f_hri_x
        f_comb_y = f_sd_y + f_hwi_y + f_hhi_y + f_hri_y        
    else:
        f_comb_x = f_sd_x + f_hwi_x + f_hhi_x
        f_comb_y = f_sd_y + f_hwi_y + f_hhi_y
    
#     print f_hhi_x, f_hhi_y
#    print f_comb_x, f_comb_y
    
    for i, ped in enumerate(crowd):
#         m = 1
#         ped.step(ax=f_comb_x[i]/m, ay=f_comb_y[i]/m)

        
        # accelarate rate limit
#         ped_accel_rate = np.sqrt( (np.square(f_comb_x[i]) + np.square(f_comb_y[i])) )
#         if ped_accel_rate > ped_accel_rate_limit:
#             f_comb_x[i] = np.multiply( f_comb_x[i], (np.divide(ped_accel_rate_limit, ped_accel_rate)) )
#             f_comb_y[i] = np.multiply( f_comb_y[i], (np.divide(ped_accel_rate_limit, ped_accel_rate)) )
        ped.step(ax=f_comb_x[i], ay=f_comb_y[i])

def render_scene(scene, robot_flag):
    for ped in crowd:
        # axis transform
        o = Point2(ped.x*amp, (ysize-ped.y)*amp) + Point2(offset, offset)
        scene.add(svg.Circle(o, radius = ped_ra, color=ped.c))
        
    if robot_flag:
        robot_o = Point2(pos_rx*amp, (ysize-pos_ry)*amp) + Point2(offset, offset)
        scene.add(svg.Circle(robot_o, radius = ped_ra, color='black'))
        
    # write text
#     text = 'Ped outflow  ' + str(ped_outflow)
#     scene.add(svg.Text((400,500), text, 20))
    clear_output(wait=True)
    display(scene)
# Out:
# /home/uri7910/anaconda2/envs/tensorflow011/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
crowd = []
init_flowAB()
numstep = 20000
for step in range(numstep):
    move_crowd(False, step)
    scene = build_scene()
    render_scene(scene, False)
    #time.sleep(0.01)
    #print step
# Out:
# <svg.Scene instance at 0x7f0cecb76c68>

# %%
accum_flow = []
for time_sec in range(len(ped_outflow)):
    accum_flow.append( sum(ped_outflow[:time_sec]) ) 
plt.plot(range(len(ped_outflow)), accum_flow)
plt.show()
ped_outflow = []
print accum_flow[-1]
# Out:
# 2770

# %%
crowd = []
init_flowAB()
numstep = 20000
for step in range(numstep):
    move_crowd(True, step)
    scene = build_scene()
    render_scene(scene, True)
    #time.sleep(0.01)
    #print step
# Out:
# <svg.Scene instance at 0x7f0d014ecb00>

# %%
accum_flow_2 = []
for time_sec in range(len(ped_outflow)):
    accum_flow_2.append( sum(ped_outflow[:time_sec]) ) 
plt.plot(range(len(ped_outflow)), accum_flow_2)
plt.show()
ped_outflow = []
print accum_flow_2[-1]
# Out:
# 2795
